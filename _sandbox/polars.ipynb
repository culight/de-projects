# %%
import polars as pl
from datetime import datetime

# %%
q = (
    pl.scan_csv("data/sfr_test.csv")
)

# %%
q.describe()
# Out:
# shape: (9, 29)
# ┌────────────┬────────────┬────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ statistic  ┆ member_uni ┆ gender ┆ dob       ┆ … ┆ rx_rebate ┆ rx_with_r ┆ rx_withou ┆ spec_cap  │
# │ ---        ┆ que_id     ┆ ---    ┆ ---       ┆   ┆ s         ┆ ebates    ┆ t_rebates ┆ ---       │
# │ str        ┆ ---        ┆ str    ┆ str       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str       │
# │            ┆ f64        ┆        ┆           ┆   ┆ str       ┆ str       ┆ str       ┆           │
# ╞════════════╪════════════╪════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ count      ┆ 10530.0    ┆ 10530  ┆ 10530     ┆ … ┆ 10530     ┆ 10530     ┆ 10530     ┆ 10530     │
# │ null_count ┆ 0.0        ┆ 0      ┆ 0         ┆ … ┆ 0         ┆ 0         ┆ 0         ┆ 0         │
# │ mean       ┆ 5265.5     ┆ null   ┆ null      ┆ … ┆ null      ┆ null      ┆ null      ┆ null      │
# ...

# %%
df = q.collect()

# %%
df
# Out:
# shape: (10_530, 28)
# ┌────────────┬────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ member_uni ┆ gender ┆ dob        ┆ eligible_ ┆ … ┆ rx_rebate ┆ rx_with_r ┆ rx_withou ┆ spec_cap  │
# │ que_id     ┆ ---    ┆ ---        ┆ year      ┆   ┆ s         ┆ ebates    ┆ t_rebates ┆ ---       │
# │ ---        ┆ str    ┆ str        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str       │
# │ i64        ┆        ┆            ┆ i64       ┆   ┆ str       ┆ str       ┆ str       ┆           │
# ╞════════════╪════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1          ┆ F      ┆ 21/06/1990 ┆ 2020      ┆ … ┆ $0.00     ┆ $0.00     ┆ $0.00     ┆ $843.78   │
# │ 2          ┆ M      ┆ 02/01/1948 ┆ 2020      ┆ … ┆ $0.00     ┆ $10,688.4 ┆ $10,859.8 ┆ $906.77   │
# │            ┆        ┆            ┆           ┆   ┆           ┆ 6         ┆ 2         ┆           │
# ...

# %%
df.filter(
    pl.col("eligible_year").is_between(2019, 2020)
)
# Out:
# shape: (10_530, 28)
# ┌────────────┬────────┬────────────┬───────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ member_uni ┆ gender ┆ dob        ┆ eligible_ ┆ … ┆ rx_rebate ┆ rx_with_r ┆ rx_withou ┆ spec_cap  │
# │ que_id     ┆ ---    ┆ ---        ┆ year      ┆   ┆ s         ┆ ebates    ┆ t_rebates ┆ ---       │
# │ ---        ┆ str    ┆ str        ┆ ---       ┆   ┆ ---       ┆ ---       ┆ ---       ┆ str       │
# │ i64        ┆        ┆            ┆ i64       ┆   ┆ str       ┆ str       ┆ str       ┆           │
# ╞════════════╪════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 1          ┆ F      ┆ 21/06/1990 ┆ 2020      ┆ … ┆ $0.00     ┆ $0.00     ┆ $0.00     ┆ $843.78   │
# │ 2          ┆ M      ┆ 02/01/1948 ┆ 2020      ┆ … ┆ $0.00     ┆ $10,688.4 ┆ $10,859.8 ┆ $906.77   │
# │            ┆        ┆            ┆           ┆   ┆           ┆ 6         ┆ 2         ┆           │
# ...

# %%
custom_df = pl.DataFrame(
    {
        "integer": [1, 2, 3],
        "date": [
            datetime(2025, 1, 1),
            datetime(2025, 1, 2),
            datetime(2025, 1, 3),
        ],
        "float": [4.0, 5.0, 6.0],
        "string": ["a", "b", "c"],
    }
)
